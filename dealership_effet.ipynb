# %%
from core_lib.core import *
from core_lib.template_config import*
from IPython.display import Video
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
texts=[['Building your dream home', 'withluxuryinterior.com', '0900-78601'],
       'high quality materials', 'good stuff', 'nice vibes']

# this will have the paths to the clips to be used. The total number of clips would be sum of the clips per block in a template.
data_path = Path('/home/farhan/Documents/pronto_25nov/pronto_gen/vid')
pronto_paths = sorted_paths(data_path)
logo_path = '/home/farhan/Documents/pronto_25nov/pronto_gen/pic/logo.jpg'

# %%
template = 'Dealership'
duration = 5

# v is the final ProntoClip created.
# temp_blocks is the list of blocks used to create the video. The same list defined in the template_config.
# You can ignore temp_blocks for now. We'll discuss it later.

v, temp_blocks = create_video(template=template, vh=540, vw=960, duration=duration, clip_paths=pronto_paths,
                              logo=logo_path, vo_file='', vo_files=[], music_file='',
                              music_files=[], texts=[texts[0],texts[1]], logger=None)
# Out:
# Exception ignored in: <function FFMPEG_VideoReader.__del__ at 0x7fb9016af3a0>
# Traceback (most recent call last):
#   File "/home/farhan/miniconda3/envs/test/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py", line 200, in __del__
#     self.close()
#   File "/home/farhan/miniconda3/envs/test/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py", line 190, in close
#     if self.proc:
# AttributeError: 'FFMPEG_VideoReader' object has no attribute 'proc'
# Exception ignored in: <function FFMPEG_VideoReader.__del__ at 0x7fb9016af3a0>
# Traceback (most recent call last):
#   File "/home/farhan/miniconda3/envs/test/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py", line 200, in __del__
#     self.close()
#   File "/home/farhan/miniconda3/envs/test/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py", line 190, in close
#     if self.proc:
# AttributeError: 'FFMPEG_VideoReader' object has no attribute 'proc'
# Exception ignored in: <function FFMPEG_VideoReader.__del__ at 0x7fb9016af3a0>
# Traceback (most recent call last):
#   File "/home/farhan/miniconda3/envs/test/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py", line 200, in __del__
#     self.close()
#   File "/home/farhan/miniconda3/envs/test/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py", line 190, in close
#     if self.proc:
# AttributeError: 'FFMPEG_VideoReader' object has no attribute 'proc'
# Exception ignored in: <function FFMPEG_VideoReader.__del__ at 0x7fb9016af3a0>
# Traceback (most recent call last):
#   File "/home/farhan/miniconda3/envs/test/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py", line 200, in __del__
#     self.close()
#   File "/home/farhan/miniconda3/envs/test/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py", line 190, in close
#     if self.proc:
# AttributeError: 'FFMPEG_VideoReader' object has no attribute 'proc'

# %%
# if using jupyter notebook in browser:

play_video(v)
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
